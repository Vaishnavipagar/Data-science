# %% [markdown]
# # Z- test :
# A Z-test is a statistical test used to determine whether there is a significant difference between sample and population means or between two sample means when the population variance is known and the sample size is large (typically n > 30)

# %% [markdown]
# # T-test :
# The t-test determines whether there is a statistically significant difference between the means of two groups.
#          Types:
#
#            1.One-sample t-test: Compares the sample mean to a known value.
#
#            2.Two-sample t-test: Compares the means of two independent groups.
#
#            3.Paired t-test: Compares the means of the same group at different times.

# %% [markdown]
# # chi- square test :
# The chi-square test is used to test the relationship between categorical variables in a contingency table.
#         Used to test if two categorical variables are independent.
#         Compares observed and expected frequencies.

# %% [markdown]
# # Anova:
#         The ANOVA test is used to determine if there are statistically significant differences between the means of three or more groups.
#
#             Types:
#               1.One-Way ANOVA: Tests one independent variable.
#               2.Two-Way ANOVA: Tests two independent variables.

# %% [markdown]
# # Inferential stat

# %%
import numpy as np
import scipy.stats as stats

# %%
sample_mean=110
population_mean=100
population_std=15
sample_size=50
alpha=0.05

# %%
confidence_interval=1-0.05

# %%
confidence_interval
# Out:
# 0.95

# %%
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(50))

# %%
z_score
# Out:
# 4.714045207910317

# %%
z_crictical=stats.norm.ppf(confidence_interval)

# %%
if z_score>z_crictical:
    print("reject the null hyphothesis")
else:
    print("fail to reject the null hyphothesis")
# Out:
# reject the null hyphothesis

# %%
p_value=1-0.9999966

# %%
if p_value<alpha:
    print("reject the null hyphothesis")
    
else:
    print("fail to reject the null hyphothesis")
# Out:
# reject the null hyphothesis

# %%
from numpy.random import randn
mydata=randn(500)

# %%
print(mydata)
# Out:
# [ 0.25658277  0.29023506  1.31534968  0.65155669  0.30847839  0.86656859
#   1.7135604  -0.56945402 -0.6291639   0.60549507  0.11812205 -1.38521526
#  -1.25962194 -1.89020066 -0.87701267 -1.96062012 -0.19251206  1.40630212
#   0.68626611  0.54859098  0.43574097 -0.31367972  2.14258959  0.73901296
#  -0.31685138  1.10846758  0.61806275 -0.96757913  0.66984301  0.40581673
#  -1.07238107 -0.95630493  1.23377384  0.23360773 -2.00106812 -1.21837045
#   1.39653685  0.1996736  -0.33375048 -0.32023181 -0.18103577 -1.44659788
#   1.79138072  0.82993944 -0.13741179 -2.02332221 -0.57067059 -1.72152431
#   0.4082332  -0.71099178  0.06554986  1.10542209  0.88304424 -0.9862664
#   1.01929749 -0.4182161   1.34543496  0.96328904  1.29951086 -0.92132067
#  -0.59721015  0.89122268  1.04275623  2.01336521 -0.07698452 -0.05805352
#  -1.03642463  0.45398318 -1.66372944  0.80091754 -0.85026488  1.08808258
#  -0.42568356  0.03206814  0.87081994  0.80025225  0.15359216  0.61419328
#   0.74099299  0.27467125 -2.09224952  1.07220806  0.87851829 -1.06128552
#   1.95255502  0.50602339  0.6586365   0.52833487  0.03088339  1.22811033
#   0.01784321 -0.65411347 -1.88944477  1.24458401  0.30083887 -1.75182088
#  -0.53159739  0.71329832 -2.07874726 -1.23875259 -0.56077936  0.18269817
py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mydata)
# <Axes: ylabel='Density'>

# %%
from scipy import stats
stats.normaltest(mydata)
# Out:
# NormaltestResult(statistic=4.073466303764623, pvalue=0.13045418953647833)

# %%
alpha=0.05
CI=0.95

# %%
sample_mean_iq=110
mean_population=100
population_std=15

# %%
population_std*randn(50)+sample_mean_iq
# Out:
# array([101.8497348 , 139.68499272, 110.94119528,  98.77535537,
#        102.13960639,  94.19139439,  96.63639424, 131.79458084,
#        131.53449875, 109.03514825, 118.4006584 , 124.49822599,
#         90.39008684, 122.79609797,  96.03625557, 114.18626588,
#        109.37242106, 114.41025402,  90.03546288,  99.03886935,
#        116.06810071, 124.44916131, 125.42958964, 132.29792771,
#        115.57370332, 122.58239887, 116.70744243, 101.92945541,
#        101.78612786,  84.96831926, 110.3627843 , 107.24528814,
#         99.73245322, 125.36514102, 108.32458758,  83.60922584,
#        106.05751559, 115.16597873, 110.79895952, 118.38441303,
#         95.16137006,  76.64670596, 101.86513738, 111.9251344 ,
#        102.43053019,  90.55998293,  98.39011633, 114.51891279,
#         98.62674019, 115.24292981])

# %%
data=population_std*randn(50)+sample_mean_iq

# %%
data
# Out:
# array([116.24907947, 132.55575254, 122.12083506,  86.20471473,
#         98.93662031,  96.23883658, 106.63152618, 115.54904681,
#        105.76190929, 120.94894809, 107.33764713, 124.03496047,
#        125.73810668,  95.30209142, 122.89631449, 108.71596072,
#        108.97022484, 124.29565643, 127.32541751, 123.82135205,
#         82.3800043 , 156.79039352, 108.71057014, 129.36319437,
#         94.27347152, 110.0981936 , 111.47543686, 129.9541716 ,
#        108.75593536, 118.03757732, 121.71364378, 107.88201438,
#        131.24590418, 130.53559859, 104.62191047, 111.69800698,
#        105.45619954, 109.01648774, 111.24495847, 126.19819746,
#        119.85105769,  96.72432821,  80.51542401, 121.97524504,
#        133.58425686, 116.65032852, 115.61172236, 108.13346998,
#        111.15061024,  84.63018231])

# %%
np.mean(data)
# Out:
# 113.35826992430405

# %%
np.std(data)
# Out:
# 14.602977734490315

# %%
null_hyphothesis=mean_population

# %%
from statsmodels.stats.weightstats import ztest
ztest(data,value=null_hyphothesis,alternative="larger")
# Out:
# (6.403343973419546, 7.600509600445974e-11)

# %%
if p_value<alpha:
    print("reject the null hyphothesis")
    
else:
    print("fail to reject the null hyphothesis")
# Out:
# reject the null hyphothesis

# %% [markdown]
# # Types of T-Test:
#
# 1.one-sample t test(with respect to one independent sample)
#
# 2.two- sample t test(with respect to two independent sample)
#
# 3.paried t-test(two sample from the same populatoin on a different time interval)

# %%
my_cricket_score=[22,38,19,15,48,11,10,49,47,38,10,25,46,10,21,24,29,36,25,25]

# %%
len(my_cricket_score)
# Out:
# 20

# %%
np.mean(my_cricket_score)
# Out:
# 27.4

# %%
sample_mean=27.4

# %% [markdown]
# # null_hyphothesis=>>population mean/true=sample mean

# %%
import scipy
result=scipy.stats.ttest_1samp(my_cricket_score,15)

# %%
result
# Out:
# TtestResult(statistic=4.131642363779888, pvalue=0.0005672503150661017, df=19)

# %%
p_value=result[1]

# %%
if p_value<=0.05:
    print("reject the null hyphothesis")

else:
    print("accept the null hyphthesis")
# Out:
# reject the null hyphothesis

# %%
scipy.stats.ttest_1samp(my_cricket_score,27.4)
# Out:
# TtestResult(statistic=0.0, pvalue=1.0, df=19)

# %%
p_value=scipy.stats.ttest_1samp(my_cricket_score,26)[1]

# %%
p_value
# Out:
# 0.6461790490703262

# %%
if p_value<=0.05:
    print("reject the null hyphothesis")

else:
    print("accept the null hyphthesis")
# Out:
# accept the null hyphthesis

# %%
#two-sample t test(with respect to two independent sample)
my_cricket_score=[22, 38, 29, 45, 48, 41, 40, 49, 47, 38, 20, 45, 46, 50, 21, 44, 29,36, 25, 24]

virat_cricket_score=[33, 45, 23, 25, 46, 46, 46, 49, 49, 44, 44, 49, 25, 31, 25, 40, 30,20, 42, 37]

# %%
first_sample_mean=np.mean(my_cricket_score)

# %%
first_sample_mean
# Out:
# 36.85

# %%
second_sample_mean=np.mean(virat_cricket_score)

# %%
second_sample_mean
# Out:
# 37.45

# %% [markdown]
# # my_null_hyphthesis=both sample mean will be equal

# %%
t_stats,pvalue=scipy.stats.ttest_ind(my_cricket_score,virat_cricket_score)

# %%
pvalue
# Out:
# 0.852719896255562

# %%
if pvalue<=0.05:
    print("reject the null hyphothesis")
else:
    print("Accept the null hyphothesis")
# Out:
# Accept the null hyphothesis

# %%
import random
population=[]
for i in range(1,51):
    population.append(random.randint(10,80))

# %%
len(population)
# Out:
# 50

# %%
my_cricket_score_from_first_inning=np.random.choice(population,size=20)

# %%
my_cricket_score_from_second_inning=np.random.choice(population,size=20)

# %%
# paired sample t test
# take a sample from sample population on different time interval

print(my_cricket_score_from_first_inning)
print(my_cricket_score_from_second_inning)
# Out:
# [79 23 39 79 17 71 26 20 75 37 73 42 20 63 50 48 52 72 20 26]
# [35 19 34 41 41 41 78 71 58 44 78 72 35 67 78 50 60 14 50 71]

# %%
my_cricket_score_from_first_inning=[8,7,14,9,17,12,46,29,8,26,19,31,46,24,44,10,13,42,25,28]

# %%
np.mean(my_cricket_score_from_first_inning)
# Out:
# 22.9

# %%
# my_null_hyphthesis=both sample mean will be equal

# %%
t_stats,p_value=scipy.stats.ttest_rel(my_cricket_score_from_first_inning,my_cricket_score_from_second_inning)

# %%
p_value
# Out:
# 4.379727863716191e-06

# %%
if p_value<=0.05:
    print("reject the null hyphothesis")
else:
    print("Accept the null hyphothesis")
# Out:
# reject the null hyphothesis

# %% [markdown]
# # The weights of 25 obese people were taken before enrolling them into the nutrition camp. The population mean weight is found to be 45 kg before starting the camp. After finishing the camp, for the same 25 people, the sample mean was found to be 75 with a standard deviation of 25. Did the fitness camp work?

# %% [markdown]
# # h0===> mu=45(sample mean is a true/population mean)
#
# # h1===> mu != 45 (two tail test)(sample mean is not a true/populatin mean)

# %%
n=25
populaiton_mean=45
sample_mean=75
sample_std=25

# %%
t_stats=(sample_mean-populaiton_mean)/(sample_std/np.sqrt(n))

# %%
t_stats
# Out:
# 6.0

# %%
sample_mean-populaiton_mean
# Out:
# 30

# %%
df=n-1

# %%
df
# Out:
# 24

# %%
alpha=0.05

# %%
CI=0.95

# %%
critical_value=stats.t.ppf(CI,df)

# %%
critical_value
# Out:
# 1.7108820799094275

# %%
print("t-stats",t_stats)
print("crtical value",critical_value)
# Out:
# t-stats 6.0
# crtical value 1.7108820799094275

# %%
p_value=1-stats.t.cdf(t_stats,df)

# %%
dataset=sns.load_dataset('tips')

# %%
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# this chi square test we peform on top of thge categorical data

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset[["sex","smoker"]]
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 239    Male     No
# 240  Female    Yes
# 241    Male    Yes
# 242    Male     No
# 243  Female     No
#
# [244 rows x 2 columns]

# %%
import pandas as pd
dataset_table=pd.crosstab(dataset["sex"],dataset["smoker"])

# %%
dataset_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
dataset_array=dataset_table.values

# %%
observed_value=dataset_array

# %%
import scipy.stats as stats

# %%
stats_test,p,dof,Expected_Value=stats.chi2_contingency(dataset_array)

# %%
Expected_Value
# Out:
# array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]])

# %%
no_of_col=dataset_table.iloc[0:2,0]

# %%
len(no_of_col)
# Out:
# 2

# %%
no_of_row=dataset_table.iloc[0,0:2]

# %%
len(no_of_row)
# Out:
# 2

# %%
dof=(len(no_of_col)-1)*(len(no_of_row)-1)

# %%
dof
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:ad22d575-8f51-4b49-817b-d3e99f46f0dc.png)

# %%
 for o,e in zip(observed_value,Expected_Value):
        print(o,e)
# Out:
# [60 97] [59.84016393 97.15983607]
# [33 54] [33.15983607 53.84016393]

# %%
from scipy.stats import chi2
chisqure=sum([(o-e)**2/e for o,e in zip(observed_value,Expected_Value)])

# %%
chisqure
# Out:
# array([0.00119737, 0.00073745])

# %%
chisqurestats=chisqure[0]+chisqure[1]

# %%
chisqurestats
# Out:
# 0.001934818536627623

# %%
alpha=0.5
Ci=0.95

# %%
critical_chi_value=chi2.ppf(Ci,df=dof)

# %%
critical_chi_value
# Out:
# 3.841458820694124

# %%
if chisqurestats>=critical_chi_value:
    print(" reject the null hyphothesis, there is a relatiuonship between two categorical variable")
else:
    print("accept the null hyphothesis there is no relation between two categorical variable")
# Out:
# accept the null hyphothesis there is no relation between two categorical variable

# %%
from scipy.stats import f_oneway

# %%
A1 = [20, 21, 19, 22, 20]
A2 = [30, 29, 31, 32, 30]
A3 = [25, 24, 26, 27, 28]

# %%
f_stat, p_value = f_oneway(A1, A2, A3)

# %%
print(f"F-Statistic: {f_stat:.3f}")
print(f"P-Value: {p_value:.3f}")
# Out:
# F-Statistic: 73.882
# P-Value: 0.000

# %% [markdown]
# # Conclusion
#
# # 1.Z-Test: For large samples or known variance.
# # 2.T-Test: For small samples or unknown variance.
# # 3.Chi-Square Test: For categorical data relationships.
# # 4.ANOVA: For comparing multiple group means.
